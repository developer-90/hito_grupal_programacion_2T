# %%
import pandas as pd

# %%
df = pd.read_csv('female_players (legacy).csv')

# %%
df
# Out:
#       player_id                                    player_url  fifa_version  \
# 0        227203  /player/227203/alexia-putellas-segura/230002            23
# 1        227125                /player/227125/sam-kerr/230002            23
# 2        227310           /player/227310/ada-hegerberg/230002            23
# 3        227316           /player/227316/wendie-renard/230002            23
# 4        226301             /player/226301/alex-morgan/230002            23
# ...         ...                                           ...           ...
# 3191     227385            /player/227385/nkem-ezurike/160002            16
# 3192     227485         /player/227485/valeria-miranda/160002            16
# 3193     228160    /player/228160/linda-tucceri-cimini/160002            16
# 3194     228723          /player/228723/fabiola-ibarra/160002            16
# 3195     228955          /player/228955/anisa-guajardo/160002            16
#
#       fifa_update fifa_update_date         short_name  \
# 0               2       2022-09-26    Alexia Putellas
# 1               2       2022-09-26            S. Kerr
# 2               2       2022-09-26       A. Hegerberg
# 3               2       2022-09-26          W. Renard
# 4               2       2022-09-26          A. Morgan
# ...           ...              ...                ...
# 3191            2       2015-09-21         N. Ezurike
# 3192            2       2015-09-21         V. Miranda
# 3193            2       2015-09-21  L. Tucceri Cimini
# 3194            2       2015-09-21          F. Ibarra
# 3195            2       2015-09-21        A. Guajardo
#
#                              long_name player_positions  overall  potential  \
# 0               Alexia Putellas Segura           CM, LW       92         92
# 1                    Samantha May Kerr               ST       91         91
# 2        Ada Martine Stolsmo Hegerberg               ST       91         92
# 3            Wéndèleine Thérèse Renard               CB       91         91
# 4            Alexandra Morgan Carrasco               ST       90         90
# ...                                ...              ...      ...        ...
# 3191                      Nkem Ezurike               ST       64         71
# 3192  Valeria Aurora Miranda Rodriguez               LB       64         72
# 3193              Linda Tucceri Cimini           LB, CB       64         71
# 3194       Claudia Fabiola Ibarra Muro               LM       63         68
# 3195       Anisa Raquel Guajardo Braff               ST       61         66
#
#       ...   cdm   rdm   rwb    lb   lcb    cb   rcb    rb    gk  \
# 0     ...  83+3  83+3  83+3  81+3  75+3  75+3  75+3  81+3  23+3
# 1     ...  61+3  61+3  66+3  63+3  59+3  59+3  59+3  63+3  21+3
# 2     ...  61+3  61+3  63+3  60+3  56+3  56+3  56+3  60+3  20+3
# 3     ...  87+3  87+3  80+3  83+3    91    91    91  83+3  21+3
# 4     ...  64+3  64+3  66+3  63+3  57+3  57+3  57+3  63+3  20+3
# ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 3191  ...    41    41    44    41    37    37    37    41    19
# 3192  ...    60    60    62    64    65    65    65    64    17
# 3193  ...    64    64    62    64    68    68    68    64    16
# 3194  ...    43    43    48    45    36    36    36    45    14
# 3195  ...    42    42    42    41    42    42    42    41    16
#
#                                         player_face_url
# 0     https://cdn.sofifa.net/players/227/203/23_120.png
# 1     https://cdn.sofifa.net/players/227/125/23_120.png
# 2     https://cdn.sofifa.net/players/227/310/23_120.png
# 3     https://cdn.sofifa.net/players/227/316/23_120.png
# 4     https://cdn.sofifa.net/players/226/301/23_120.png
# ...                                                 ...
# 3191  https://cdn.sofifa.net/players/227/385/16_120.png
# 3192  https://cdn.sofifa.net/players/227/485/16_120.png
# 3193  https://cdn.sofifa.net/players/228/160/16_120.png
# 3194  https://cdn.sofifa.net/players/228/723/16_120.png
# 3195  https://cdn.sofifa.net/players/228/955/16_120.png
#
# [3196 rows x 110 columns]

# %%
df.sort_values(by=['potential'], ascending=False)
df[['short_name', 'potential']]
# Out:
#              short_name  potential
# 0       Alexia Putellas         92
# 1               S. Kerr         91
# 2          A. Hegerberg         92
# 3             W. Renard         91
# 4             A. Morgan         90
# ...                 ...        ...
# 3191         N. Ezurike         71
# 3192         V. Miranda         72
# 3193  L. Tucceri Cimini         71
# 3194          F. Ibarra         68
# 3195        A. Guajardo         66
#
# [3196 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# %%
tencol = df.head(20)
x = tencol.short_name
y = tencol.potential
plt.barh(x, y)
plt.show()

# %%
jugadoras_nacionalidad = tencol.groupby('nationality_name').size().reset_index(name='Jugadoras')
plt.pie(jugadoras_nacionalidad['Jugadoras'], labels=jugadoras_nacionalidad['nationality_name'],autopct='%1.1f%%')
plt.axis('equal')
plt.title('Número de jugadoras por país')

# Mostrar el gráfico
plt.show()

# %%
tencols = df.head(30)
colores = ['red', 'blue', 'green', 'yellow']
promedio_edad = tencols.groupby('club_name').mean().reset_index()
for i, equipo in enumerate(promedio_edad['club_name']):
    plt.bar(equipo, promedio_edad.loc[i, 'age'], color=colores[i % len(colores)])
    plt.text(equipo, promedio_edad.loc[i, 'age'], round(promedio_edad.loc[i, 'age'], 2), ha='center', va='bottom')


plt.xlabel('Equipo')
plt.ylabel('Promedio de edad')
plt.title('Promedio de edad por equipo')

# Mostrar el gráfico
plt.show()
